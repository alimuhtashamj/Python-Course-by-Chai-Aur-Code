# %%
# users = [
#     {"name": "Ali", "age": 22, "degree": True},
#     {"name": "Sara", "age": 19, "degree": True},
#     {"name": "John", "age": 25, "degree": False},
#     {"name": "Ayesha", "age": 28, "degree": True}
# ]

# def extract_name(name,age,degree): # user should have been called here, not the inside stuff
#     extracted_names = []
#     for i in users: # if the user is not called in the function, this is coming outside of the func
#         if age >= 21 and degree:
#           extracted_names.append(i) #names are not extracted this way
#     return extracted_names

# %%
users = [
    {"name": "Ali", "age": 22, "degree": True},
    {"name": "Sara", "age": 19, "degree": True},
    {"name": "John", "age": 25, "degree": False},
    {"name": "Ayesha", "age": 28, "degree": True}
]

def extract_name(users):
    extracted_names = []
    for i in users:
        if i['age'] >= 21 and i['degree']:
          extracted_names.append(i['name'])
    return extracted_names
