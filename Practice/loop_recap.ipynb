# %%
for i in range(1,11):
    print(i)

# %%
n = 5 
sum = 0
for i in range(n+1):
    sum += i
print(sum)

# %%
n = '1234'
for i in range(-1,-len(n)-1, -1):
    print(n[i], end ='')

# %%
while True:
    user_input = input('are you a male?')
    
    if user_input.lower() == 'yes':
     break
