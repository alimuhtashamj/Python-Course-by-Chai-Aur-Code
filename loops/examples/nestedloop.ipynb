# %%
results = []
for i in [2,4,6]:
    column = []
    for j in [10,20]:
      column.append(i*j)
      results.append(column)
    #   runs twice because inner loop runs twice
print(results)
# Out:
# [[20, 40], [20, 40], [40, 80], [40, 80], [60, 120], [60, 120]]

# %%
results = []
for i in [2,4,6]:
    column = []
    for j in [10,20]:
      column.append(i*j)
    results.append(column)
    # runs thrice for outer loop
print(results)
# Out:
# [[20, 40], [40, 80], [60, 120]]
